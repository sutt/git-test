# %%
import os, sys

# %%
myroot = "c:/users/wsutt_000/desktop/tickets/"
d = []
for root, subdirs, f in os.walk(myroot):
    try:
        d.append(os.path.join(root,f))
    except:
        print root, f
len(d)
# Out:
# ['.ipynb_checkpoints', 'april10', 'availability', 'backup12.15', 'backup_2.8', 'browse', 'chrome_ext2', 'FullTM_files', 'lyman', 'march', 'march26', 'NovEarly', 'postgre', 'PySelTests', 'scrape1', 'subproc', 'tickets-early', 'tickets-october', 'tickets-september', 'tips', 'wlan', 'wp_webapp']
# []
# ['.ipynb_checkpoints', 'procs']
# []
# ['.ipynb_checkpoints']
# []
# ['.ipynb_checkpoints']
# []
# []
# ['.git']
# ['hooks', 'info', 'objects', 'refs']
# []
# []
# ['info', 'pack']
# []
# []
# ['heads', 'tags']
# []
# []
# []
# ['tut1']
# []
# []
# ['.fseventsd', '.Spotlight-V100', '.Trashes', 'source', 'tk-sourcecode-2014-12-27']
# []
# ['Store-V1']
# ['Stores']
# ['56BCDD44-992E-467B-A350-3403DEBCFD6A']
# []
# []
# ['etc', 'h', 'lib', 'root', 'usr']
# ...

# %%
d[:1]
# Out:
# [['12.15 WLAN_Toggle-checkpoint.ipynb',
#   '12.16 AIMPORT toogle-checkpoint.ipynb',
#   '12.16 wlan modules-checkpoint.ipynb',
#   '12.17 selenium waits-checkpoint.ipynb',
#   '12.17 Subproc and WindowSize-checkpoint.ipynb',
#   '12.23 wait_to_jsclick_search-checkpoint.ipynb',
#   'download-checkpoint.ipynb',
#   'Monday Night-checkpoint.ipynb',
#   'Monday-checkpoint.ipynb',
#   'parseEvents1-checkpoint.ipynb',
#   'scrape_meta1-checkpoint.ipynb',
#   'Untitled-checkpoint.ipynb',
#   'Untitled0-checkpoint.ipynb',
#   'Untitled1-checkpoint.ipynb',
#   'Untitled10-checkpoint.ipynb',
#   'Untitled11-checkpoint.ipynb',
#   'Untitled12-checkpoint.ipynb',
#   'Untitled2-checkpoint.ipynb',
#   'Untitled3-checkpoint.ipynb',
#   'Untitled4-checkpoint.ipynb',
#   'Untitled5-checkpoint.ipynb',
#   'Untitled6-checkpoint.ipynb',
#   'Untitled7-checkpoint.ipynb',
#   'Untitled8-checkpoint.ipynb',
#   'Untitled9-checkpoint.ipynb',
#   'W2_Sunday-checkpoint.ipynb',
# ...
